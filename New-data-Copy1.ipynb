# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime as dt

# %%
data=pd.read_excel('sheet-for-cod2.xlsx')

# %%
data.head()
# Out:
#        Date  HOUR  KP  DST    TEC  Class
# 0  25-08-13     0  10  -23  13.27      0
# 1  25-08-13     1  10  -21  15.73      0
# 2  25-08-13     2  10  -16  19.39      0
# 3  25-08-13     3  17  -11  23.93      0
# 4  25-08-13     4  17   -9  27.94      0

# %%
data['Class'].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
feature_df=data[['HOUR','KP','DST','TEC']]
x=np.asarray(feature_df)
y=np.asarray(data['Class'])
np.unique(y)
# Out:
# array([0, 1, 2], dtype=int64)

# %%
y = np.where(y==2,1,y)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20 ,random_state=4)

# %%
from sklearn import svm
Classifier=svm.SVC(kernel='linear',gamma='auto',C=2)
Classifier.fit(x_train, y_train)
y_pred=Classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.56      0.60       150
#            1       0.60      0.68      0.63       143
#
#     accuracy                           0.62       293
#    macro avg       0.62      0.62      0.62       293
# weighted avg       0.62      0.62      0.62       293

# %%
Training = y_train[y_train==0]
Training_1 = y_train[y_train==1]
Classified = y_pred[y_pred==0]
Classified_1 = y_pred[y_pred==1]

# %%
plt.scatter(np.where(y_train==0)[0], x[np.where(y_train==0)[0], 3], color='blue',label='(0)Training',marker= '*')
plt.scatter(np.where(y_pred==0)[0], x[np.where(y_pred==0)[0], 3], color='black',label='(0)Classified',marker= '+')
plt.scatter(np.where(y_train==1)[0], x[np.where(y_train==1)[0], 3],label='(1)Training',marker= '*', color='red')
plt.scatter(np.where(y_pred==1)[0], x[np.where(y_pred==1)[0], 3],color='lightgreen',label='(1)Classified',marker= '+')
plt.legend(loc="upper right")
plt.xlabel("Index")
plt.ylabel("TEC")
plt.show()

# %%
plt.scatter(x[np.where(y_train==0)[0], 1], x[np.where(y_train==0)[0], 3], color='blue',label='(0)Training',marker= '*')
plt.scatter(x[np.where(y_pred==0)[0],1], x[np.where(y_pred==0)[0], 3], color='black',label='(0)Classified',marker= '+')
plt.scatter(x[np.where(y_train==1)[0],1], x[np.where(y_train==1)[0], 3],label='(1)Training',marker= '*', color='red')
plt.scatter(x[np.where(y_pred==1)[0],1], x[np.where(y_pred==1)[0], 3],color='lightgreen',label='(1)Classified',marker= '+')
plt.legend(loc="upper right")
plt.xlabel("KP")
plt.ylabel("TEC")
plt.show()

# %%
plt.scatter(x[np.where(y_train==0)[0], 2], x[np.where(y_train==0)[0], 3], color='blue',label='(0)Training',marker= '*')
plt.scatter(x[np.where(y_pred==0)[0],2], x[np.where(y_pred==0)[0], 3], color='black',label='(0)Classified',marker= '+')
plt.scatter(x[np.where(y_train==1)[0],2], x[np.where(y_train==1)[0], 3],label='(1)Training',marker= '*', color='red')
plt.scatter(x[np.where(y_pred==1)[0],2], x[np.where(y_pred==1)[0], 3],color='lightgreen',label='(1)Classified',marker= '+')
plt.legend(loc="upper right")
plt.xlabel("DST")
plt.ylabel("TEC")
plt.show()

# %% [markdown]
# # No Need To Thanks cruel!

# %%
print("\U0001f600")
# Out:
# 😀
